# %%
import pandas as pd

# %%
df1 = pd.read_csv("../dados/22-11-2023_NEGOCIOSAVISTA_FLRY3_2359.csv", delimiter=";", decimal=",")
df2 = pd.read_csv("../dados/17-11-2023_NEGOCIOSAVISTA_FLRY3.csv", delimiter=";", decimal=",")
df3 = pd.read_csv("../dados/20-11-2023_NEGOCIOSAVISTA_FLRY3.csv", delimiter=";", decimal=",")
df4 = pd.read_csv("../dados/21-11-2023_NEGOCIOSAVISTA_FLRY3.csv", delimiter=";", decimal=",")

frames = [df1, df2, df3, df4]

df = pd.concat(frames)
df
# Out:
#       DataReferencia CodigoInstrumento  AcaoAtualizacao  PrecoNegocio  \
# 0         2023-11-22             FLRY3                0         17.01
# 1         2023-11-22             FLRY3                0         17.01
# 2         2023-11-22             FLRY3                0         17.01
# 3         2023-11-22             FLRY3                0         17.01
# 4         2023-11-22             FLRY3                0         17.01
# ...              ...               ...              ...           ...
# 10373     2023-11-21             FLRY3                0         17.01
# 10374     2023-11-21             FLRY3                0         17.01
# 10375     2023-11-21             FLRY3                0         17.01
# 10376     2023-11-21             FLRY3                0         17.01
# 10377     2023-11-21             FLRY3                0         17.01
#
#        QuantidadeNegociada  HoraFechamento  CodigoIdentificadorNegocio  \
# 0                      100       100300025                          10
# 1                      700       100300025                          20
# 2                      200       100300025                          30
# 3                      100       100300025                          40
# 4                      200       100300025                          50
# ...                    ...             ...                         ...
# 10373                  100       180600045                      103740
# 10374                 1400       180600045                      103750
# 10375                 2100       180600045                      103760
# 10376                  100       180600045                      103770
# 10377                  200       180600045                      103780
#
#        TipoSessaoPregao DataNegocio  CodigoParticipanteComprador  \
# 0                     1  2023-11-22                           40
# 1                     1  2023-11-22                           40
# 2                     1  2023-11-22                           40
# 3                     1  2023-11-22                          120
# 4                     1  2023-11-22                          120
# ...                 ...         ...                          ...
# 10373                 1  2023-11-21                            3
# 10374                 1  2023-11-21                            3
# 10375                 1  2023-11-21                           40
# 10376                 1  2023-11-21                           40
# 10377                 1  2023-11-21                           40
#
#        CodigoParticipanteVendedor
# 0                              40
# 1                              40
# 2                             308
# 3                             308
# 4                               3
# ...                           ...
# 10373                         114
# 10374                         238
# 10375                         238
# 10376                         238
# 10377                         238
#
# [46664 rows x 11 columns]

# %%
df['HoraFechamento'] = df['HoraFechamento'].astype(str)
df['HoraFechamento'] = df['HoraFechamento'].apply(lambda x: x[0:4])
df['DataNegocio'] = df['DataNegocio'].apply(lambda x: x.replace('-', ''))
df['HoraFechamento'] = df['HoraFechamento'] + df['DataNegocio']
df['HoraFechamento'] = pd.to_datetime(df['HoraFechamento'], format="%H%M%Y%m%d")
df.drop(columns=['DataNegocio'], axis=1, inplace=True)
df
# Out:
#       DataReferencia CodigoInstrumento  AcaoAtualizacao  PrecoNegocio  \
# 0         2023-11-22             FLRY3                0         17.01
# 1         2023-11-22             FLRY3                0         17.01
# 2         2023-11-22             FLRY3                0         17.01
# 3         2023-11-22             FLRY3                0         17.01
# 4         2023-11-22             FLRY3                0         17.01
# ...              ...               ...              ...           ...
# 10373     2023-11-21             FLRY3                0         17.01
# 10374     2023-11-21             FLRY3                0         17.01
# 10375     2023-11-21             FLRY3                0         17.01
# 10376     2023-11-21             FLRY3                0         17.01
# 10377     2023-11-21             FLRY3                0         17.01
#
#        QuantidadeNegociada      HoraFechamento  CodigoIdentificadorNegocio  \
# 0                      100 2023-11-22 10:03:00                          10
# 1                      700 2023-11-22 10:03:00                          20
# 2                      200 2023-11-22 10:03:00                          30
# 3                      100 2023-11-22 10:03:00                          40
# 4                      200 2023-11-22 10:03:00                          50
# ...                    ...                 ...                         ...
# 10373                  100 2023-11-21 18:06:00                      103740
# 10374                 1400 2023-11-21 18:06:00                      103750
# 10375                 2100 2023-11-21 18:06:00                      103760
# 10376                  100 2023-11-21 18:06:00                      103770
# 10377                  200 2023-11-21 18:06:00                      103780
#
#        TipoSessaoPregao  CodigoParticipanteComprador  \
# 0                     1                           40
# 1                     1                           40
# 2                     1                           40
# 3                     1                          120
# 4                     1                          120
# ...                 ...                          ...
# 10373                 1                            3
# 10374                 1                            3
# 10375                 1                           40
# 10376                 1                           40
# 10377                 1                           40
#
#        CodigoParticipanteVendedor
# 0                              40
# 1                              40
# 2                             308
# 3                             308
# 4                               3
# ...                           ...
# 10373                         114
# 10374                         238
# 10375                         238
# 10376                         238
# 10377                         238
#
# [46664 rows x 10 columns]

# %%
df['PrecoNegocio'].plot(kind='hist', edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#df.groupby(pd.Grouper(key='HoraFechamento', freq='15T'))['PrecoNegocio'].mean().plot(kind='hist', edgecolor='black')
df.sort_values(by=['HoraFechamento']).groupby(pd.Grouper(key='HoraFechamento', freq='20T'))[['PrecoNegocio', 'HoraFechamento']].last().plot(kind='hist', edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>
